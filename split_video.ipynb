# %%
from moviepy.editor import *

FILE_NAME="TEST.mp4"

#切り出し開始時刻。秒で表現
start = 30
end = 40

OUT_FILE_NAME=str(start)+"-"+str(end)+"_"+FILE_NAME

save_path = "sample_cut.mp4"#編集後のファイル保存先とパス

video = VideoFileClip("base_video/"+FILE_NAME).subclip(start, end)#ビデオのカット開始

video.write_videofile("split_video/"+OUT_FILE_NAME,fps=60) # Many options...#書き込み
# Out:
# chunk:  71%|███████   | 157/221 [06:35<00:00, 335.65it/s, now=None]
#
# ...
# chunk:   1%|          | 2/221 [03:41<6:43:48, 110.63s/it, now=None]
#
# chunk:   0%|          | 0/221 [00:00<?, ?it/s, now=None]
#
# chunk:  14%|█▎        | 30/221 [00:00<00:00, 299.23it/s, now=None]Moviepy - Building video split_video/30-40_TEST.mp4.
# MoviePy - Writing audio in 30-40_TESTTEMP_MPY_wvf_snd.mp3
#
#
# chunk:  45%|████▌     | 100/221 [00:00<00:00, 360.80it/s, now=None]
#
# chunk:  84%|████████▍ | 186/221 [00:00<00:00, 436.86it/s, now=None]
#
#
# chunk:  71%|███████   | 157/221 [06:35<00:00, 335.65it/s, now=None]
#
# ...
# chunk:   1%|          | 2/221 [03:41<6:44:32, 110.83s/it, now=None]
#
# t:   0%|          | 0/600 [00:00<?, ?it/s, now=None]MoviePy - Done.
# Moviepy - Writing video split_video/30-40_TEST.mp4
#
#
#
# t:   1%|          | 6/600 [00:00<00:12, 47.65it/s, now=None]
#
# t:   2%|▏         | 10/600 [00:00<00:13, 43.85it/s, now=None]
#
# ...
